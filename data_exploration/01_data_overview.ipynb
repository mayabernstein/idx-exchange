# %%
import pandas as pd

# %% [markdown]
# #### **Creating Two Separate Files for Newly Listed and Sold Properties**

# %% [markdown]
# ##### Newly Listed Properties

# %% [markdown]
# ##### 2024 Listings

# %%
'''
df_list = []
for i in range(1, 13):
    file_path = f"../data/Listing/CRMLSListing2024{i:02d}.csv"
        
    print(f"Reading file: {file_path}")
    df_listing = pd.read_csv(file_path, encoding="ISO-8859-1")
    df_list.append(df_listing)
  
df_listings_2024 = pd.concat(df_list, ignore_index=True)
'''
# Out:
# '\ndf_list = []\nfor i in range(1, 13):\n    file_path = f"../data/Listing/CRMLSListing2024{i:02d}.csv"\n\n    print(f"Reading file: {file_path}")\n    df_listing = pd.read_csv(file_path, encoding="ISO-8859-1")\n    df_list.append(df_listing)\n\ndf_listings_2024 = pd.concat(df_list, ignore_index=True)\n'

# %%
# df_listings_2024['Year'] = 2024
# df_listings_2024.to_csv("../data/Listing/listed_transactions_2024.csv", index=False)

# %% [markdown]
# ##### 2025 Listings

# %%
'''
df_list = []
for i in range(1, 13):
    file_path = f"../data/Listing/CRMLSListing2025{i:02d}.csv"
        
    print(f"Reading file: {file_path}")
    df_listing = pd.read_csv(file_path, encoding="ISO-8859-1")
    df_list.append(df_listing)
  
df_listings_2025 = pd.concat(df_list, ignore_index=True)
'''
# Out:
# '\ndf_list = []\nfor i in range(1, 13):\n    file_path = f"../data/Listing/CRMLSListing2025{i:02d}.csv"\n\n    print(f"Reading file: {file_path}")\n    df_listing = pd.read_csv(file_path, encoding="ISO-8859-1")\n    df_list.append(df_listing)\n\ndf_listings_2025 = pd.concat(df_list, ignore_index=True)\n'

# %%
#df_listings_2025['Year'] = 2025
#df_listings_2025.to_csv("../data/Listing/listed_transactions_2025.csv", index=False)

# %% [markdown]
# ##### 2026 Listings

# %%
'''
df_list = []
for i in range(1, 4):
    file_path = f"../data/Listing/CRMLSListing2026{i:02d}.csv"
        
    print(f"Reading file: {file_path}")
    df_listing = pd.read_csv(file_path, encoding="ISO-8859-1")
    df_list.append(df_listing)
  
df_listings_2026 = pd.concat(df_list, ignore_index=True)
'''
# Out:
# '\ndf_list = []\nfor i in range(1, 4):\n    file_path = f"../data/Listing/CRMLSListing2026{i:02d}.csv"\n\n    print(f"Reading file: {file_path}")\n    df_listing = pd.read_csv(file_path, encoding="ISO-8859-1")\n    df_list.append(df_listing)\n\ndf_listings_2026 = pd.concat(df_list, ignore_index=True)\n'

# %%
#df_listings_2026['Year'] = 2026
#df_listings_2026.to_csv("../data/Listing/listed_transactions_2026.csv", index=False)

# %% [markdown]
# ##### 2024 to 2026 Listings

# %%
df_listings_2024 = pd.read_csv("../data/Listing/listed_transactions_2024.csv", encoding="ISO-8859-1")
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_13972\2195753770.py:1: DtypeWarning: Columns (0: BuyerAgencyCompensationType) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listings_2024 = pd.read_csv("../data/Listing/listed_transactions_2024.csv", encoding="ISO-8859-1")
# ...

# %%
df_listings_2025 = pd.read_csv("../data/Listing/listed_transactions_2025.csv", encoding="ISO-8859-1")

# %%
df_listings_2026 = pd.read_csv("../data/Listing/listed_transactions_2026.csv", encoding="ISO-8859-1")
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_13972\4126579556.py:1: DtypeWarning: Columns (0: ListAgentEmail, 1: ElementarySchool, 2: BuilderName, 3: BusinessType, 4: MiddleOrJuniorSchool) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listings_2026 = pd.read_csv("../data/Listing/listed_transactions_2026.csv", encoding="ISO-8859-1")

# %%
df_listings = pd.concat([df_listings_2024, df_listings_2025, df_listings_2026], ignore_index=True)

# %%
df_listings.shape
# Out:
# (853754, 85)

# %%
df_listings['Year'].value_counts()
# Out:
# Year
# 2024    383920
# 2025    363315
# 2026    106519
# Name: count, dtype: int64

# %%
# df_listings.to_csv("../data/Listing/listed_transactions.csv", index=False)

# %%
df_listings = pd.read_csv("../data/Listing/listed_transactions.csv", encoding="ISO-8859-1")
df_listings.head()
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_13972\974492464.py:1: DtypeWarning: Columns (0: ListAgentEmail, 1: BuyerAgencyCompensationType) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listings = pd.read_csv("../data/Listing/listed_transactions.csv", encoding="ISO-8859-1")
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0            90000.0  1075010398                miriamlara03@gmail.com
# 1          1500000.0  1074974457                  janelle@judsonre.com
# 2          1340000.0  1074973329                    haleh360@Gmail.com
# 3          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 4          3150000.0  1074936537                      anader@dppre.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN             Miriam              Lara  34.097939
# 1       NaN         NaN            Janelle            Judson  33.121241
# ...

# %%
df_listings['Year'].value_counts()
# Out:
# Year
# 2024    383920
# 2025    363315
# 2026    106519
# Name: count, dtype: int64

# %%
df_listings.shape
# Out:
# (853754, 85)

# %% [markdown]
# ##### Closed/Sold Properties

# %% [markdown]
# ##### 2024 Sold Listings

# %%
'''
df_sold = []
for i in range(1, 13):
    file_path = f"../data/Sold/CRMLSSold2024{i:02d}.csv"
        
    print(f"Reading file: {file_path}")
    df_selling = pd.read_csv(file_path, encoding="ISO-8859-1")
    df_sold.append(df_selling)
  
df_sold_2024 = pd.concat(df_sold, ignore_index=True)
'''
# Out:
# Reading file: ../data/Sold/CRMLSSold202401.csv
# Reading file: ../data/Sold/CRMLSSold202402.csv
# Reading file: ../data/Sold/CRMLSSold202403.csv
# Reading file: ../data/Sold/CRMLSSold202404.csv
# C:\Users\mayab\AppData\Local\Temp\ipykernel_7676\987517719.py:6: DtypeWarning: Columns (0: WaterfrontYN, 1: ElementarySchool, 2: BuilderName, 3: CoBuyerAgentFirstName, 4: PostalCode) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_selling = pd.read_csv(file_path, encoding="ISO-8859-1")
# Reading file: ../data/Sold/CRMLSSold202405.csv
# Reading file: ../data/Sold/CRMLSSold202406.csv
# Reading file: ../data/Sold/CRMLSSold202407.csv
# Reading file: ../data/Sold/CRMLSSold202408.csv
# Reading file: ../data/Sold/CRMLSSold202409.csv
# Reading file: ../data/Sold/CRMLSSold202410.csv
# Reading file: ../data/Sold/CRMLSSold202411.csv
# Reading file: ../data/Sold/CRMLSSold202412.csv

# %%
#df_sold_2024['Year'] = 2024
#df_sold_2024.to_csv("../data/Sold/sold_transactions_2024.csv", index=False)

# %% [markdown]
# ##### 2025 Sold Listings

# %%
'''
df_sold = []
for i in range(1, 13):
    file_path = f"../data/Sold/CRMLSSold2025{i:02d}.csv"
        
    print(f"Reading file: {file_path}")
    df_selling = pd.read_csv(file_path, encoding="ISO-8859-1")
    df_sold.append(df_selling)
  
df_sold_2025 = pd.concat(df_sold, ignore_index=True)
'''
# Out:
# Reading file: ../data/Sold/CRMLSSold202501.csv
# Reading file: ../data/Sold/CRMLSSold202502.csv
# Reading file: ../data/Sold/CRMLSSold202503.csv
# Reading file: ../data/Sold/CRMLSSold202504.csv
# Reading file: ../data/Sold/CRMLSSold202505.csv
# Reading file: ../data/Sold/CRMLSSold202506.csv
# C:\Users\mayab\AppData\Local\Temp\ipykernel_7676\1639992141.py:6: DtypeWarning: Columns (0: WaterfrontYN) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_selling = pd.read_csv(file_path, encoding="ISO-8859-1")
# Reading file: ../data/Sold/CRMLSSold202507.csv
# Reading file: ../data/Sold/CRMLSSold202508.csv
# Reading file: ../data/Sold/CRMLSSold202509.csv
# Reading file: ../data/Sold/CRMLSSold202510.csv
# Reading file: ../data/Sold/CRMLSSold202511.csv
# Reading file: ../data/Sold/CRMLSSold202512.csv

# %%
# df_sold_2025['Year'] = 2025
#df_sold_2025.to_csv("../data/Sold/sold_transactions_2025.csv", index=False)

# %% [markdown]
# ##### 2026 Sold Listings

# %%
'''
df_sold = []
for i in range(1, 4):
    file_path = f"../data/Sold/CRMLSSold2026{i:02d}.csv"
        
    print(f"Reading file: {file_path}")
    df_selling = pd.read_csv(file_path, encoding="ISO-8859-1")
    df_sold.append(df_selling)
  
df_sold_2026 = pd.concat(df_sold, ignore_index=True)
'''
# Out:
# '\ndf_sold = []\nfor i in range(1, 4):\n    file_path = f"../data/Sold/CRMLSSold2026{i:02d}.csv"\n\n    print(f"Reading file: {file_path}")\n    df_selling = pd.read_csv(file_path, encoding="ISO-8859-1")\n    df_sold.append(df_selling)\n\ndf_sold_2026 = pd.concat(df_sold, ignore_index=True)\n'

# %%
# df_sold_2026['Year'] = 2026
# df_sold_2026.to_csv("../data/Sold/sold_transactions_2026.csv", index=False)

# %% [markdown]
# ##### 2024 to 2026 Closed/Sold Listings

# %%
df_sold_2024 = pd.read_csv("../data/Sold/sold_transactions_2024.csv", encoding="ISO-8859-1")
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_13972\4106193620.py:1: DtypeWarning: Columns (0: BuyerAgentAOR, 1: ListAgentAOR, 2: OriginatingSystemName, 3: OriginatingSystemSubName, 4: BuyerAgencyCompensationType, 5: latfilled, 6: lonfilled) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sold_2024 = pd.read_csv("../data/Sold/sold_transactions_2024.csv", encoding="ISO-8859-1")

# %%
df_sold_2025 = pd.read_csv("../data/Sold/sold_transactions_2025.csv", encoding="ISO-8859-1")
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_13972\1935601661.py:1: DtypeWarning: Columns (0: WaterfrontYN, 1: latfilled, 2: lonfilled) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sold_2025 = pd.read_csv("../data/Sold/sold_transactions_2025.csv", encoding="ISO-8859-1")

# %%
df_sold_2026 = pd.read_csv("../data/Sold/sold_transactions_2026.csv", encoding="ISO-8859-1")
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_13972\3313316751.py:1: DtypeWarning: Columns (0: WaterfrontYN, 1: ListAgentEmail, 2: OriginatingSystemName, 3: OriginatingSystemSubName) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sold_2026 = pd.read_csv("../data/Sold/sold_transactions_2026.csv", encoding="ISO-8859-1")

# %%
df_sold_listings = pd.concat([df_sold_2024, df_sold_2025, df_sold_2026], ignore_index=True)

# %%
df_sold_listings['Year'].value_counts()
# Out:
# Year
# 2024    272491
# 2025    260104
# 2026     58520
# Name: count, dtype: int64

# %%
# df_sold_listings.to_csv("../data/Sold/sold_transactions.csv", index=False)

# %%
df_sold_listings = pd.read_csv("../data/Sold/sold_transactions.csv", encoding="ISO-8859-1")
df_sold_listings.head()
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_13972\2392212637.py:1: DtypeWarning: Columns (0: BuyerAgentAOR, 1: ListAgentAOR, 2: WaterfrontYN, 3: ListAgentEmail, 4: OriginatingSystemName, 5: OriginatingSystemSubName, 6: BuyerAgencyCompensationType, 7: latfilled, 8: lonfilled) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sold_listings = pd.read_csv("../data/Sold/sold_transactions.csv", encoding="ISO-8859-1")
#               BuyerAgentAOR              ListAgentAOR          Flooring  \
# 0               Mlslistings               Mlslistings  Carpet,Tile,Wood
# 1                HighDesert                HighDesert               NaN
# 2              OrangeCounty              OrangeCounty               NaN
# 3             InlandValleys             InlandValleys               NaN
# 4  SouthwestRiversideCounty  SouthwestRiversideCounty               NaN
#
#   ViewYN WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# ...

# %%
df_sold_listings.shape
# Out:
# (591115, 85)

# %%
df_sold_listings['Year'].value_counts()
# Out:
# Year
# 2024    272491
# 2025    260104
# 2026     58520
# Name: count, dtype: int64
