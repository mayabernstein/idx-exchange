# %%
import pandas as pd

# %% [markdown]
# #### **Creating Two Separate Files for Newly Listed and Sold Properties**

# %% [markdown]
# ##### Newly Listed Properties

# %%
'''
This code reads multiple CSV files containing real estate listings
df_list = []
for i in range(2024, 2027):
    stop_condition = False
    for j in range(1, 13):
        file_path = f"../data/Listing/CRMLSListing{i}{j:02d}.csv"
        
        if i == 2026 and j == 4:
            stop_condition = True
            break
        print(f"Reading file: {file_path}")
        df_listing = pd.read_csv(file_path, encoding="ISO-8859-1")
        df_list.append(df_listing)
    if stop_condition:
        break
df_listings = pd.concat(df_list, ignore_index=True)
'''
# Out:
# '\nThis code reads multiple CSV files containing real estate listings\ndf_list = []\nfor i in range(2024, 2027):\n    stop_condition = False\n    for j in range(1, 13):\n        file_path = f"../data/Listing/CRMLSListing{i}{j:02d}.csv"\n\n        if i == 2026 and j == 4:\n            stop_condition = True\n            break\n        print(f"Reading file: {file_path}")\n        df_listing = pd.read_csv(file_path, encoding="ISO-8859-1")\n        df_list.append(df_listing)\n    if stop_condition:\n        break\ndf_listings = pd.concat(df_list, ignore_index=True)\n'

# %%
# df_listings.to_csv("../data/Listing/listed_transactions.csv", index=False)

# %%
df_listings = pd.read_csv("../data/Listing/listed_transactions.csv", encoding="ISO-8859-1")
df_listings.head()
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_18104\974492464.py:1: DtypeWarning: Columns (0: ListAgentEmail, 1: BuyerAgencyCompensationType) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listings = pd.read_csv("../data/Listing/listed_transactions.csv", encoding="ISO-8859-1")
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0            90000.0  1075010398                miriamlara03@gmail.com
# 1          1500000.0  1074974457                  janelle@judsonre.com
# 2          1340000.0  1074973329                    haleh360@Gmail.com
# 3          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 4          3150000.0  1074936537                      anader@dppre.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN             Miriam              Lara  34.097939
# 1       NaN         NaN            Janelle            Judson  33.121241
# ...

# %%
df_listings.shape
# Out:
# (853754, 84)

# %% [markdown]
# ##### Closed/Sold Properties

# %%
'''
This code reads multiple CSV files containing real estate sold listings
df_sold = []
for i in range(2024, 2027):
    stop_condition = False
    for j in range(1, 13):
        file_path = f"../data/Sold/CRMLSSold{i}{j:02d}.csv"
        
        if i == 2026 and j == 4:
            stop_condition = True
            break
        print(f"Reading file: {file_path}")
        df_sold.append(df_sold)
    if stop_condition:
        break
df_sold_listings = pd.concat(df_sold, ignore_index=True)
'''
# Out:
# '\nThis code reads multiple CSV files containing real estate sold listings\ndf_sold = []\nfor i in range(2024, 2027):\n    stop_condition = False\n    for j in range(1, 13):\n        file_path = f"../data/Sold/CRMLSSold{i}{j:02d}.csv"\n\n        if i == 2026 and j == 4:\n            stop_condition = True\n            break\n        print(f"Reading file: {file_path}")\n        df_sold.append(df_sold)\n    if stop_condition:\n        break\ndf_sold_listings = pd.concat(df_sold, ignore_index=True)\n'

# %%
# df_sold_listings.to_csv("../data/Sold/sold_transactions.csv", index=False)

# %%
df_sold_listings = pd.read_csv("../data/Sold/sold_transactions.csv", encoding="ISO-8859-1")
df_sold_listings.head()
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_18104\2392212637.py:1: DtypeWarning: Columns (0: BuyerAgentAOR, 1: ListAgentAOR, 2: WaterfrontYN, 3: ListAgentEmail, 4: OriginatingSystemName, 5: OriginatingSystemSubName, 6: BuyerAgencyCompensationType, 7: latfilled, 8: lonfilled) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sold_listings = pd.read_csv("../data/Sold/sold_transactions.csv", encoding="ISO-8859-1")
#               BuyerAgentAOR              ListAgentAOR          Flooring  \
# 0               Mlslistings               Mlslistings  Carpet,Tile,Wood
# 1                HighDesert                HighDesert               NaN
# 2              OrangeCounty              OrangeCounty               NaN
# 3             InlandValleys             InlandValleys               NaN
# 4  SouthwestRiversideCounty  SouthwestRiversideCounty               NaN
#
#   ViewYN WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# ...

# %%
df_sold_listings.shape
# Out:
# (591115, 84)
