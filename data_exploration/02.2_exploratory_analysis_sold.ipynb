# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Closed/Sold Properties**

# %%
df_sold = pd.read_csv("../data/Sold/sold_transactions.csv", encoding="ISO-8859-1")
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_30944\3090260199.py:1: DtypeWarning: Columns (0: BuyerAgentAOR, 1: ListAgentAOR, 2: WaterfrontYN, 3: ListAgentEmail, 4: OriginatingSystemName, 5: OriginatingSystemSubName, 6: BuyerAgencyCompensationType, 7: latfilled, 8: lonfilled) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sold = pd.read_csv("../data/Sold/sold_transactions.csv", encoding="ISO-8859-1")

# %%
df_sold.head()
# Out:
#               BuyerAgentAOR              ListAgentAOR          Flooring  \
# 0               Mlslistings               Mlslistings  Carpet,Tile,Wood
# 1                HighDesert                HighDesert               NaN
# 2              OrangeCounty              OrangeCounty               NaN
# 3             InlandValleys             InlandValleys               NaN
# 4  SouthwestRiversideCounty  SouthwestRiversideCounty               NaN
#
#   ViewYN WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0   True          NaN        NaN         False           499000.0   551985747
# 1    NaN          NaN        NaN           NaN                0.0   535486633
# 2   True          NaN        NaN           NaN            75000.0   529986282
# 3   True          NaN        NaN           NaN           199000.0   529618166
# 4   True          NaN        NaN           NaN            19500.0   522614340
#
# ...

# %%
df_sold.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
# ...

# %%
df_sold.describe()
# Out:
#        OriginalListPrice    ListingKey    ClosePrice       Latitude  \
# count       5.894040e+05  5.911150e+05  5.911080e+05  572099.000000
# mean        9.061188e+05  1.095901e+09  8.745653e+05      34.527335
# std         5.745172e+06  3.325868e+07  5.275319e+06       1.614966
# min         0.000000e+00  4.214490e+08  0.000000e+00    -117.472493
# 25%         6.500000e+04  1.075086e+09  5.250000e+04      33.739575
# 50%         6.399900e+05  1.095288e+09  6.299000e+05      34.038490
# 75%         1.089000e+06  1.117368e+09  1.070000e+06      34.304213
# max         1.390000e+09  1.156473e+09  9.895000e+08     157.000000
#
#            Longitude    LivingArea     ListPrice   DaysOnMarket  \
# count  572271.000000  5.493900e+05  5.902050e+05  591115.000000
# mean     -118.451190  3.497121e+03  8.400098e+05      43.284872
# std         3.113572  1.226711e+06  1.275660e+06      69.834015
# min      -177.646696  0.000000e+00  0.000000e+00    -288.000000
# ...

# %%
df_sold.isna().sum()
# Out:
# BuyerAgentAOR                   71507
# ListAgentAOR                    68046
# Flooring                       243651
# ViewYN                          59190
# WaterfrontYN                   590793
#                                 ...
# BuyerAgencyCompensationType    523368
# BuyerAgencyCompensation        523335
# latfilled                      495322
# lonfilled                      495322
# Year                                0
# Length: 85, dtype: int64

# %%
df_sold.dtypes
# Out:
# BuyerAgentAOR                      str
# ListAgentAOR                       str
# Flooring                           str
# ViewYN                          object
# WaterfrontYN                    object
#                                 ...
# BuyerAgencyCompensationType        str
# BuyerAgencyCompensation        float64
# latfilled                       object
# lonfilled                       object
# Year                             int64
# Length: 85, dtype: object

# %% [markdown]
# #### Numerical and Categorical Variables

# %%
df_num_sold = df_sold.select_dtypes(include=['number'])
df_num_sold.shape
# Out:
# (591115, 32)

# %%
df_num_sold.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ClosePrice', 'Latitude',
#        'Longitude', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'FireplacesTotal', 'AboveGradeFinishedArea', 'ListingKeyNumeric',
#        'TaxAnnualAmount', 'ParkingTotal', 'LotSizeAcres', 'YearBuilt',
#        'StreetNumberNumeric', 'BathroomsTotalInteger', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ElementarySchoolDistrict',
#        'BelowGradeFinishedArea', 'CoveredSpaces', 'Stories', 'LotSizeArea',
#        'MainLevelBedrooms', 'GarageSpaces', 'AssociationFee',
#        'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict',
#        'BuyerAgencyCompensation', 'Year'],
#       dtype='str')

# %%
df_cat_sold = df_sold.select_dtypes(include=['object', 'category', 'str'])
df_cat_sold.shape
# Out:
# (591115, 53)

# %%
df_cat_sold.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'ListAgentEmail', 'CloseDate',
#        'ListAgentFirstName', 'ListAgentLastName', 'UnparsedAddress',
#        'PropertyType', 'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'AssociationFeeFrequency', 'MLSAreaMajor', 'CountyOrParish',
#        'MlsStatus', 'ElementarySchool', 'AttachedGarageYN', 'BuilderName',
#        'PropertySubType', 'SubdivisionName', 'BuyerOfficeAOR', 'ListingId',
#        'City', 'ContractStatusChangeDate', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BusinessType',
#        'StateOrProvince', 'MiddleOrJuniorSchool', 'FireplaceYN', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'NewConstructionYN',
# ...

# %% [markdown]
# #### Listing Contract Date

# %%
df_sold['ListingContractDate'].isna().sum()
# Out:
# np.int64(83)

# %%
df_sold['ListingContractDate']
# Out:
# 0         2021-10-06
# 1         2021-08-06
# 2         2021-07-18
# 3         2021-07-14
# 4         2021-06-07
#              ...
# 591110    2021-10-19
# 591111    2018-10-10
# 591112    2018-04-27
# 591113    2019-09-09
# 591114    2020-02-20
# Name: ListingContractDate, Length: 591115, dtype: str

# %%
df_sold['Month'] = pd.to_datetime(df_sold['ListingContractDate']).dt.month_name()
df_sold['Month'].value_counts()
# Out:
# Month
# January      62719
# May          53241
# February     52232
# April        52145
# March        51415
# July         49742
# October      49657
# June         49331
# September    47561
# August       47302
# November     40206
# December     35481
# Name: count, dtype: int64

# %%
df_sold_2024 = df_sold[df_sold['Year'] == 2024]

# %%
df_sold_2025 = df_sold[df_sold['Year'] == 2025]

# %%
df_sold_2026 = df_sold[df_sold['Year'] == 2026]

# %% [markdown]
# ##### Original List Prices Across Contract Months

# %%
original_monthly_prices_2024 = df_sold_2024.groupby('Month')['OriginalListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
original_monthly_prices_2024
# Out:
#         Month  OriginalListPrice
# 0    December      720331.645023
# 1    November      805914.891439
# 2        July      835615.765133
# 3     October      853761.459391
# 4      August      862594.968736
# 5     January      868850.047122
# 6    February      891668.845927
# 7   September      901052.549116
# 8        June      923408.944491
# 9       March      926569.548659
# 10      April      943453.795682
# 11        May      969993.036463

# %%
original_monthly_prices_2025 = df_sold_2025.groupby('Month')['OriginalListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
original_monthly_prices_2025
# Out:
#         Month  OriginalListPrice
# 0    December       7.303517e+05
# 1        June       8.772326e+05
# 2     October       8.827262e+05
# 3      August       8.842093e+05
# 4   September       9.012483e+05
# 5     January       9.449254e+05
# 6       April       9.704978e+05
# 7    February       9.802584e+05
# 8       March       9.802714e+05
# 9        July       9.846100e+05
# 10        May       1.009764e+06
# 11   November       1.009899e+06

# %%
original_monthly_prices_2026 = df_sold_2026.groupby('Month')['OriginalListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
original_monthly_prices_2026
# Out:
#         Month  OriginalListPrice
# 0    December       7.020924e+05
# 1       March       7.447511e+05
# 2    November       7.905046e+05
# 3     January       8.197037e+05
# 4     October       8.953411e+05
# 5    February       9.703569e+05
# 6   September       9.730019e+05
# 7      August       1.040450e+06
# 8       April       1.089724e+06
# 9        June       1.120568e+06
# 10       July       1.136263e+06
# 11        May       1.575114e+06

# %%
plt.figure(figsize=(8,5))
sns.lineplot(data=df_sold, x="Month", y="OriginalListPrice", hue='Year', marker='o')
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.ylabel("Avg. Original List Price")
plt.show()

# %%
df_sold.groupby(['Year', 'Month']).size()
# Out:
# Year  Month
# 2024  April        26834
#       August       23599
#       December     13112
#       February     22299
#       January      23283
#       July         24462
#       June         25037
#       March        24633
#       May          27744
#       November     17048
#       October      22076
#       September    22324
# 2025  April        24866
#       August       21554
#       December     13197
#       February     21334
#       January      24045
#       July         23790
#       June         23353
#       March        24454
#       May          24826
#       November     15694
#       October      21343
#       September    21614
# 2026  April          445
#       August        2149
#       December      9172
#       February      8599
#       January      15391
#       July          1490
#       June           941
#       March         2328
#       May            671
#       November      7464
#       October       6238
#       September     3623
# ...

# %% [markdown]
# ##### Listed Prices across Contract Listing Months

# %%
monthly_prices_2024 = df_sold_2024.groupby('Month')['ListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
monthly_prices_2024
# Out:
#         Month      ListPrice
# 0    December  670710.780164
# 1    November  785942.045308
# 2     January  811749.758172
# 3        July  818055.529951
# 4      August  828824.776455
# 5     October  837884.847435
# 6    February  857880.907393
# 7        June  859869.356920
# 8   September  879244.243829
# 9       March  883041.091287
# 10        May  901054.997417
# 11      April  907124.918081

# %%
monthly_prices_2025 = df_sold_2025.groupby('Month')['ListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
monthly_prices_2025
# Out:
#         Month      ListPrice
# 0    December  714582.398824
# 1    November  759881.320039
# 2      August  794578.162485
# 3        July  801215.798831
# 4     October  821978.962553
# 5   September  844471.943493
# 6        June  845023.364908
# 7     January  873009.036172
# 8         May  880826.152975
# 9       April  881726.594973
# 10   February  891495.686214
# 11      March  893553.889445

# %%
monthly_prices_2026 = df_sold_2026.groupby('Month')['ListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
monthly_prices_2026
# Out:
#         Month     ListPrice
# 0    December  6.611355e+05
# 1       March  7.409618e+05
# 2    November  7.740587e+05
# 3    February  7.878087e+05
# 4     January  8.092286e+05
# 5     October  8.628845e+05
# 6   September  9.252633e+05
# 7        July  9.551094e+05
# 8       April  9.808058e+05
# 9      August  9.808940e+05
# 10       June  1.011546e+06
# 11        May  1.026447e+06

# %%
plt.figure(figsize=(8,5))
sns.lineplot(data=df_sold, x="Month", y="ListPrice", hue='Year', marker='o')
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.ylabel("Avg. List Price")
plt.show()

# %% [markdown]
# #### Missing Values

# %%
df_sold.shape[0]
# Out:
# 591115

# %%
df_sold.isna().sum().sort_values(ascending=False).head(20)
# Out:
# FireplacesTotal                 591115
# MiddleOrJuniorSchoolDistrict    591115
# ElementarySchoolDistrict        591115
# CoveredSpaces                   591115
# AboveGradeFinishedArea          591115
# WaterfrontYN                    590793
# TaxYear                         590748
# BusinessType                    589483
# TaxAnnualAmount                 588608
# BelowGradeFinishedArea          588525
# BasementYN                      581377
# BuilderName                     568536
# LotSizeDimensions               560102
# CoBuyerAgentFirstName           543114
# OriginatingSystemSubName        531106
# OriginatingSystemName           531106
# ElementarySchool                525530
# MiddleOrJuniorSchool            525089
# BuyerAgencyCompensationType     523368
# BuyerAgencyCompensation         523335
# dtype: int64

# %% [markdown]
# For data cleaning, the variables that are missing a significant number of rows will be dropped after further investigation and analysis of the variables.

# %% [markdown]
# Variables with only missing values:
# - FireplacesTotal
# - MiddleOrJuniorSchoolDistrict
# - ElementarySchoolDistrict
# - CoveredSpaces
# - AboveGradeFinishedArea

# %% [markdown]
# #### Year Built

# %%
df_sold['YearBuilt'].describe()
# Out:
# count    566201.000000
# mean       1978.099567
# std          27.085939
# min        1776.000000
# 25%        1960.000000
# 50%        1979.000000
# 75%        1999.000000
# max        2026.000000
# Name: YearBuilt, dtype: float64

# %%
df_sold['YearBuilt'].hist(figsize=(8, 5))
# Out:
# <Axes: >

# %% [markdown]
# Similar as listed properties; there is a right-skewed

# %% [markdown]
# #### City

# %%
df_sold['City'].value_counts().reset_index()
# Out:
#                City  count
# 0       Los Angeles  39599
# 1         San Diego  23197
# 2            Irvine  11554
# 3          San Jose  10410
# 4        Long Beach   7683
# ...             ...    ...
# 1232           Clio      1
# 1233        El Nido      1
# 1234      Lost City      1
# 1235  Stirling City      1
# 1236     Strathmore      1
#
# [1237 rows x 2 columns]

# %%
top_15_cities = df_sold[df_sold['City'].isin(df_sold['City'].value_counts().head(15).index)]

# %%
top_15_cities['City'].value_counts().plot(kind='bar', figsize=(8, 5))
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# #### Property Types

# %%
df_sold['PropertyType'].value_counts().plot(kind='bar', figsize=(8,5), rot=45)
# Out:
# <Axes: xlabel='PropertyType'>

# %%
pd.unique(df_sold['PropertyType'])
# Out:
# <StringArray>
# [        'Residential',     'CommercialLease',                'Land',
#     'ResidentialLease',  'ManufacturedInPark',   'ResidentialIncome',
#       'CommercialSale', 'BusinessOpportunity']
# Length: 8, dtype: str

# %%
df_sold['PropertyType'].value_counts()
# Out:
# PropertyType
# Residential            397218
# ResidentialLease       135469
# Land                    19322
# ManufacturedInPark      16059
# ResidentialIncome       15832
# CommercialSale           3709
# CommercialLease          3103
# BusinessOpportunity       403
# Name: count, dtype: int64

# %%
# Distribution of property type 
dist_property = (df_sold['PropertyType'].value_counts() / len(df_sold)) * 100
dist_property
# Out:
# PropertyType
# Residential            67.198092
# ResidentialLease       22.917537
# Land                    3.268738
# ManufacturedInPark      2.716730
# ResidentialIncome       2.678328
# CommercialSale          0.627458
# CommercialLease         0.524940
# BusinessOpportunity     0.068176
# Name: count, dtype: float64

# %% [markdown]
# CommercialSale, CommercialLease, and BusinessOpportunity may be removed since there is a small distribution of those properties, which mean that they may not contribute a significant amount statistical power to the future modeling.
