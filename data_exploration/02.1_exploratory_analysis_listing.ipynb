# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Sold data only includes properties that have been successfully closed in the given time. The listings include all properties that entered the market, including thosse that are still active or that failed to sell.

# %% [markdown]
# ### **Listed Properties**

# %%
df_listing = pd.read_csv("../data/Listing/listed_transactions.csv", encoding="ISO-8859-1")
# Out:
# C:\Users\mayab\AppData\Local\Temp\ipykernel_23884\2095627017.py:1: DtypeWarning: Columns (0: ListAgentEmail, 1: BuyerAgencyCompensationType) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listing = pd.read_csv("../data/Listing/listed_transactions.csv", encoding="ISO-8859-1")

# %%
df_listing.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'CloseDate',
#        'ClosePrice', 'ListAgentFirstName', 'ListAgentLastName', 'Latitude',
#        'Longitude', 'UnparsedAddress', 'PropertyType', 'LivingArea',
#        'ListPrice', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'CoListOfficeName', 'ListAgentFullName', 'CoListAgentFirstName',
#        'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency',
#        'AboveGradeFinishedArea', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'TaxAnnualAmount', 'CountyOrParish', 'PropertyType.1', 'MlsStatus',
#        'ElementarySchool', 'ListAgentFirstName.1', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1',
#        'BuyerAgencyCompensationType', 'StreetNumberNumeric', 'LivingArea.1',
# ...

# %%
df_listing_2024 = df_listing[df_listing['Year'] == 2024]

# %%
df_listing_2025 = df_listing[df_listing['Year'] == 2025]

# %%
df_listing_2026 = df_listing[df_listing['Year'] == 2026]

# %%
df_listing.head()
# Out:
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0            90000.0  1075010398                miriamlara03@gmail.com
# 1          1500000.0  1074974457                  janelle@judsonre.com
# 2          1340000.0  1074973329                    haleh360@Gmail.com
# 3          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 4          3150000.0  1074936537                      anader@dppre.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN             Miriam              Lara  34.097939
# 1       NaN         NaN            Janelle            Judson  33.121241
# 2       NaN         NaN              Haleh       Dowlatshahi  34.052207
# 3       NaN         NaN              Renee              Chen  33.496363
# 4       NaN         NaN           Margaret             Nader  34.119345
#
#     Longitude                UnparsedAddress  ... NewConstructionYN  \
# ...

# %%
df_listing.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 853754 entries, 0 to 853753
# Data columns (total 85 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   OriginalListPrice             850444 non-null  float64
#  1   ListingKey                    853754 non-null  int64
#  2   ListAgentEmail                780379 non-null  str
#  3   CloseDate                     255893 non-null  str
#  4   ClosePrice                    233059 non-null  float64
#  5   ListAgentFirstName            848740 non-null  str
#  6   ListAgentLastName             853678 non-null  str
#  7   Latitude                      741807 non-null  float64
#  8   Longitude                     742511 non-null  float64
#  9   UnparsedAddress               851597 non-null  str
#  10  PropertyType                  853754 non-null  str
#  11  LivingArea                    747280 non-null  float64
# ...

# %%
df_listing.isna().sum()
# Out:
# OriginalListPrice                 3310
# ListingKey                           0
# ListAgentEmail                   73375
# CloseDate                       597861
# ClosePrice                      620695
#                                  ...
# AssociationFee                  275935
# LotSizeSquareFeet                78866
# MiddleOrJuniorSchoolDistrict    853754
# UnparsedAddress.1                 2157
# Year                                 0
# Length: 85, dtype: int64

# %%
df_listing.describe()
# Out:
#        OriginalListPrice    ListingKey    ClosePrice       Latitude  \
# count       8.504440e+05  8.537540e+05  2.330590e+05  741807.000000
# mean        1.051204e+06  1.105018e+09  7.814101e+05      34.519429
# std         6.389884e+06  2.997089e+07  3.457756e+06       1.885437
# min         0.000000e+00  4.216549e+08  0.000000e+00    -117.472493
# 25%         8.500000e+04  1.077489e+09  5.000000e+03      33.757746
# 50%         6.399000e+05  1.104373e+09  5.655000e+05      34.051480
# 75%         1.150000e+06  1.127476e+09  1.025000e+06      34.302492
# max         1.390000e+09  1.156493e+09  8.200000e+08     737.000000
#
#            Longitude    LivingArea     ListPrice   DaysOnMarket  \
# count  742511.000000  7.472800e+05  8.516190e+05  853754.000000
# mean     -118.364684  3.159316e+03  9.842293e+05      19.143911
# std         3.884846  1.051825e+06  2.167942e+06      28.847418
# min      -159.523315  0.000000e+00  0.000000e+00     -58.000000
# ...

# %%
df_listing.dtypes
# Out:
# OriginalListPrice               float64
# ListingKey                        int64
# ListAgentEmail                      str
# CloseDate                           str
# ClosePrice                      float64
#                                  ...
# AssociationFee                  float64
# LotSizeSquareFeet               float64
# MiddleOrJuniorSchoolDistrict    float64
# UnparsedAddress.1                   str
# Year                              int64
# Length: 85, dtype: object

# %% [markdown]
# #### Numerical and Categorical Variables

# %%
df_num_listing = df_listing.select_dtypes(include=['number'])
df_num_listing.shape
# Out:
# (853754, 37)

# %%
df_num_listing.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ClosePrice', 'Latitude',
#        'Longitude', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'FireplacesTotal', 'AboveGradeFinishedArea', 'ListingKeyNumeric',
#        'TaxAnnualAmount', 'ParkingTotal', 'LotSizeAcres', 'YearBuilt',
#        'DaysOnMarket.1', 'StreetNumberNumeric', 'LivingArea.1',
#        'BathroomsTotalInteger', 'BuyerAgencyCompensation', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'Longitude.1',
#        'ElementarySchoolDistrict', 'BelowGradeFinishedArea', 'Latitude.1',
#        'ListPrice.1', 'CoveredSpaces', 'Stories', 'LotSizeArea',
#        'MainLevelBedrooms', 'GarageSpaces', 'AssociationFee',
#        'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict', 'Year'],
#       dtype='str')

# %%
df_cat_listing = df_listing.select_dtypes(include=['object', 'category', 'str'])
df_cat_listing.shape
# Out:
# (853754, 48)

# %%
df_cat_listing.columns
# Out:
# Index(['ListAgentEmail', 'CloseDate', 'ListAgentFirstName',
#        'ListAgentLastName', 'UnparsedAddress', 'PropertyType',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'AssociationFeeFrequency', 'MLSAreaMajor', 'CountyOrParish',
#        'PropertyType.1', 'MlsStatus', 'ElementarySchool',
#        'ListAgentFirstName.1', 'AttachedGarageYN', 'BuilderName',
#        'PropertySubType', 'SubdivisionName', 'BuyerOfficeAOR',
#        'BuyerAgencyCompensationType', 'ListingId', 'City',
#        'ContractStatusChangeDate', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BusinessType',
#        'StateOrProvince', 'MiddleOrJuniorSchool', 'FireplaceYN', 'HighSchool',
#        'Levels', 'ListAgentLastName.1', 'CloseDate.1', 'LotSizeDimensions',
# ...

# %% [markdown]
# #### Listing Contract Date

# %%
df_listing['ListingContractDate'].isna().sum() # Use this variable to see how the price change
# Out:
# np.int64(0)

# %%
df_listing['ListingContractDate']
# Out:
# 0         2024-01-29
# 1         2024-01-11
# 2         2024-01-01
# 3         2024-01-24
# 4         2024-01-12
#              ...
# 853749    2026-03-02
# 853750    2026-03-12
# 853751    2026-03-18
# 853752    2026-03-25
# 853753    2026-03-25
# Name: ListingContractDate, Length: 853754, dtype: str

# %%
df_listing['Month'] = pd.to_datetime(df_listing['ListingContractDate']).dt.month_name()
df_listing['Month'].value_counts()
# Out:
# Month
# March        109625
# January      100225
# February      93796
# May           79067
# April         76690
# July          63685
# October       62316
# June          62292
# September     61548
# August        60515
# November      45805
# December      38190
# Name: count, dtype: int64

# %%
df_listing_2024 = df_listing[df_listing['Year'] == 2024]

# %%
df_listing_2025 = df_listing[df_listing['Year'] == 2025]

# %%
df_listing_2026 = df_listing[df_listing['Year'] == 2026]

# %% [markdown]
# ##### Original List Prices Across Contract Months

# %%
original_monthly_prices_2024 = df_listing_2024.groupby('Month')['OriginalListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
original_monthly_prices_2024
# Out:
#         Month  OriginalListPrice
# 0    December       8.380585e+05
# 1    November       9.107836e+05
# 2     October       9.744429e+05
# 3     January       1.003460e+06
# 4    February       1.022396e+06
# 5        July       1.037260e+06
# 6        June       1.046878e+06
# 7       March       1.055786e+06
# 8   September       1.060720e+06
# 9      August       1.061498e+06
# 10      April       1.071125e+06
# 11        May       1.125731e+06

# %%
original_monthly_prices_2025 = df_listing_2025.groupby('Month')['OriginalListPrice'].mean().sort_values(ascending=True).reset_index()
original_monthly_prices_2025
# Out:
#         Month  OriginalListPrice
# 0        June       9.072132e+05
# 1      August       9.284713e+05
# 2    December       9.389559e+05
# 3        July       9.573065e+05
# 4     October       9.635291e+05
# 5   September       9.799895e+05
# 6    November       1.070927e+06
# 7       April       1.088548e+06
# 8     January       1.136112e+06
# 9       March       1.147397e+06
# 10   February       1.183687e+06
# 11        May       1.185055e+06

# %%
original_monthly_prices_2026 = df_listing_2026.groupby('Month')['OriginalListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
original_monthly_prices_2026
# Out:
#       Month  OriginalListPrice
# 0   January       1.086357e+06
# 1     March       1.111471e+06
# 2  February       1.120841e+06

# %%
plt.figure(figsize=(8,5))
sns.lineplot(data=df_listing, x="Month", y="OriginalListPrice", hue='Year', marker='o')
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.ylabel("Avg. Original List Price")
plt.show()

# %%
df_listing.groupby(['Year', 'Month']).size()
# Out:
# Year  Month
# 2024  April        36503
#       August       35305
#       December     19417
#       February     27447
#       January      27454
#       July         36340
#       June         35893
#       March        32282
#       May          38796
#       November     25128
#       October      34730
#       September    34625
# 2025  April        40187
#       August       25210
#       December     18773
#       February     33983
#       January      37469
#       July         27345
#       June         26399
#       March        38492
#       May          40271
#       November     20677
#       October      27586
#       September    26923
# 2026  February     32366
#       January      35302
#       March        38851
# dtype: int64

# %% [markdown]
# December has lower listed properties

# %% [markdown]
# ##### Listed Prices across Contract Listing Months

# %%
monthly_prices_2024 = df_listing_2024.groupby('Month')['ListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
monthly_prices_2024
# Out:
#         Month     ListPrice
# 0    December  7.754391e+05
# 1    November  8.949971e+05
# 2     January  9.358645e+05
# 3     October  9.529126e+05
# 4        July  9.581458e+05
# 5    February  9.596700e+05
# 6      August  9.626102e+05
# 7       March  1.000743e+06
# 8        June  1.013638e+06
# 9   September  1.022890e+06
# 10      April  1.047444e+06
# 11        May  1.061820e+06

# %%
monthly_prices_2025 = df_listing_2025.groupby('Month')['ListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
monthly_prices_2025
# Out:
#         Month     ListPrice
# 0    December  8.087207e+05
# 1        July  8.292539e+05
# 2      August  8.313208e+05
# 3    November  8.542641e+05
# 4        June  8.761998e+05
# 5   September  8.835212e+05
# 6     October  9.069327e+05
# 7       April  1.059348e+06
# 8         May  1.074989e+06
# 9     January  1.076681e+06
# 10      March  1.087480e+06
# 11   February  1.096205e+06

# %%
monthly_prices_2026 = df_listing_2026.groupby('Month')['ListPrice'].mean().sort_index().sort_values(ascending=True).reset_index()
monthly_prices_2026
# Out:
#       Month     ListPrice
# 0  February  1.033490e+06
# 1   January  1.036524e+06
# 2     March  1.068052e+06

# %%
plt.figure(figsize=(8,5))
sns.lineplot(data=df_listing, x="Month", y="ListPrice", hue='Year', marker='o')
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.ylabel("Avg. List Price")
plt.show()

# %% [markdown]
# #### Missing Values

# %%
df_listing.shape[0]
# Out:
# 853754

# %%
df_test = pd.read_csv("../data/Listing/CRMLSListing202401.csv")
df_test['MiddleOrJuniorSchoolDistrict'].isna().sum()
# Out:
# np.int64(27454)

# %%
df_test.shape
# Out:
# (27454, 84)

# %%
df_listing.isna().sum().sort_values(ascending=False).head(20)
# Out:
# AboveGradeFinishedArea          853754
# MiddleOrJuniorSchoolDistrict    853754
# ElementarySchoolDistrict        853754
# CoveredSpaces                   853754
# FireplacesTotal                 853754
# TaxYear                         852886
# BelowGradeFinishedArea          850334
# BusinessType                    847779
# TaxAnnualAmount                 847661
# CoBuyerAgentFirstName           834049
# BuilderName                     824452
# LotSizeDimensions               805053
# ElementarySchool                774463
# MiddleOrJuniorSchool            774371
# HighSchool                      749412
# BuyerAgencyCompensation         730235
# BuyerAgencyCompensationType     730216
# BuildingAreaTotal               716869
# CoListAgentFirstName            683440
# CoListAgentLastName             682952
# dtype: int64

# %% [markdown]
# For data cleaning, the variables that are missing a significant number of rows will be dropped after further investigation and analysis of the variables.

# %% [markdown]
# Variables with only missing values:
# - MiddleOrJuniorSchoolDistrict
# - ElementarySchoolDistrict
# - CoveredSpaces
# - AboveGradeFinishedArea
# - FireplacesTotal

# %% [markdown]
# #### Year Built

# %%
df_listing['YearBuilt'].describe()
# Out:
# count    784284.000000
# mean       1978.400254
# std          28.041624
# min        1776.000000
# 25%        1960.000000
# 50%        1979.000000
# 75%        2001.000000
# max        2028.000000
# Name: YearBuilt, dtype: float64

# %%
df_listing['YearBuilt'].hist(figsize=(8, 5))
# Out:
# <Axes: >

# %% [markdown]
# Oldest house built in 1776 and latest being in 2028. There are more "newer" houses than older (left-skewed).

# %% [markdown]
# #### City

# %%
df_listing['City'].value_counts().reset_index()
# Out:
#              City  count
# 0     Los Angeles  68689
# 1       San Diego  33853
# 2        San Jose  15433
# 3          Irvine  13929
# 4      Long Beach   9964
# ...           ...    ...
# 1319     Rosarito      1
# 1320     Crenshaw      1
# 1321   Pilot Hill      1
# 1322       Penryn      1
# 1323   Parker Dam      1
#
# [1324 rows x 2 columns]

# %%
top_15_cities = df_listing[df_listing['City'].isin(df_listing['City'].value_counts().head(15).index)]

# %%
top_15_cities['City'].value_counts().plot(kind='bar', figsize=(8, 5))
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# #### Property Types

# %%
df_listing['PropertyType'].value_counts().plot(kind='bar', figsize=(8,5), rot=45)
# Out:
# <Axes: xlabel='PropertyType'>

# %%
pd.unique(df_listing['PropertyType'])
# Out:
# <bound method StringArray.value_counts of <StringArray>
# [ 'ManufacturedInPark',      'CommercialSale',         'Residential',
#     'ResidentialLease',                'Land',   'ResidentialIncome',
#      'CommercialLease', 'BusinessOpportunity']
# Length: 8, dtype: str>

# %%
df_listing['PropertyType'].value_counts()
# Out:
# PropertyType
# Residential            540580
# ResidentialLease       178410
# Land                    56355
# ResidentialIncome       31683
# ManufacturedInPark      24536
# CommercialSale          11719
# CommercialLease          7739
# BusinessOpportunity      2732
# Name: count, dtype: int64

# %%
# Distribution of property type 
dist_property = (df_listing['PropertyType'].value_counts() / len(df_listing)) * 100
dist_property
# Out:
# PropertyType
# Residential            63.318005
# ResidentialLease       20.897120
# Land                    6.600848
# ResidentialIncome       3.711022
# ManufacturedInPark      2.873896
# CommercialSale          1.372644
# CommercialLease         0.906467
# BusinessOpportunity     0.319999
# Name: count, dtype: float64

# %% [markdown]
# CommericalLease and BusinessOpportunity may have to be removed.
